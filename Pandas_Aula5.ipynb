# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieleite/CienciadeDados_Aula5/blob/main/Pandas_Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gráficos Continuação

# %%
import matplotlib.pyplot as plt #Biblioteca gráfica
import pandas as pd
import numpy as np # Arrays númericos 
import seaborn as sns # biblioteca gráfica extendida da mtplotlib

# %matplotlib inline

# %%
mtcars = pd.read_csv("http://emsapi.esy.es/datasets/mtcars.csv", index_col=0)

# %%
sns.pairplot(mtcars.loc[:,'mpg':'hp'])
plt.show()

# %% [markdown]
# # Relações Lineares, Quadráticas e Cúbicas

# %%
x = np.linspace(0, 2, 100) # cria números entre o valor inicial e o final, indicados nos parâmetros

# %%
# Criando um gráfico Linear
plt.plot(x, x)

# %%
# Relação Quadrática
plt.plot(x, x**2)
plt.show()

# %%
# Quadrática completa
x = np.linspace(-2, 2, 100)

# %%
plt.plot(x, x**2)
plt.show()

# %%
# Gráficos para relações cúbicas
x = np.linspace(0, 2, 100)
plt.plot(x, x**3)
plt.show()

# %%
# Gráficos para relações cúbicas compĺetas
x = np.linspace(-2, 2, 100)
plt.plot(x, x**3)
plt.show()

# %%
x = np.linspace(-2, 2, 100)
plt.plot(x, x**4)
plt.show()

# %%
# Como colar então tudo em um lugar só? 
x = np.linspace(-2, 2, 100)

plt.plot(x, x) #reta
plt.plot(x, x**2) #parábola
plt.plot(x, x**3) # curva
plt.show()

# %%
# Personalizando o gráfico
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# habilitando a exposiçã de legendas
plt.legend()
plt.show()

# %%
# Personalizando o gráfico
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# habilitando a exposição de legendas
plt.legend()

# habilitar um grid
plt.grid(True)

plt.show()

# %%
# Personalizando o gráfico
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# habilitando a exposição de legendas
plt.legend(fontsize='x-large')

# habilitar um grid
plt.grid(True)

plt.show()

# %%
from seaborn.rcmod import set_style
import matplotlib.font_manager as font_manager

# Personalizando o gráfico
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# habilitando a exposição de legendas
font = font_manager.FontProperties(family='DejaVu Sans', 
                                   weight='bold', 
                                   style='italic', size=12)
plt.legend(prop=font)
#plt.legend(fontsize='x-large', set_style: {style='italic'})

# habilitar um grid
plt.grid(True)

plt.show()

# %%
# Personalizando o gráfico
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# configurando textos (título e eixos)
plt.title('Exemplo de Gráfico com Personalização')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

# habilitando a exposição de legendas
plt.legend()

# habilitar um grid
plt.grid(True)

plt.show()

# %%
# Exagerando no texto do eixo Y
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# configurando textos (títulos e eixos)
plt.title('Exemplo de Gráfico de Persnalização')
plt.xlabel('Eixo X')
plt.ylabel('Esse aqui é o eixos Y\nesto escrevendo um monte de texto\nassim fica um exemplo')

# habilitando a exposição de legendas
plt.legend()

# habilitar um grid 
plt.grid(True)

plt.show()

# %%
# Aplicando estilos nas fontes
x = np.linspace(-2, 2, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

# configurando textos (títulos e eixos)
plt.title('Exemplo de Gráfico com Personalização', size=18)
plt.xlabel('Eixo X', size=16, style='italic')
plt.ylabel('Esse aqui é o eixo Y\nestou escrevendo um monte de texto\nassim fica um exemplo legal')

# habilitando a exposição de legendas 
plt.legend()

# habilitar um grid
plt.grid(True)

plt.show()

# %%
# Atividade para esquentar os motores 
# Criar uma função que permita mosrar um gráfico, a partir da configuração de alguns parâmetros.
def grafico(start, end, titulo, eixo_x, eixo_y, arquivo):
  x = np.linspace(start, end, 100)

  plt.plot(x, x, label='Linear')
  plt.plot(x, x, label='Quadrática')
  plt.plot(x, x, label='Cúbica')

  plt.title(titulo, size=18)
  plt.xlabel(eixo_x, size=14, style='italic')
  plt.ylabel(eixo_y, size=14, style='italic')
  plt.legend()

  plt.grid(True)

  plt.savefig(arquivo + '.png', dpi=100)
  plt.show()

# %%
grafico(0, 3, 'Outro Gráfico feito com função', 'Batatinha', 'Maça', 'arquivo_02')

# %%
# recuando as margens 
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
# aplicar inclinação nos eixos (textos)
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, label='Linear')
plt.plot(x, x**2, label='Quadrática')
plt.plot(x, x**3, label='Cúbica')

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.xticks(ticks=np.linspace(start, end, 9),
           rotation=45) # rotação em graus

#plt.yticks(
#    ticks=np.linspace(-8, 8, 9),
#    labels=['Tom', 'Dick', 'Sue', 'Tom', 'Dick', 'Sue','Tom', 'Dick', 'Sue']
#    )

# Mr. Handerson
plt.yticks(
    [-8, -6, -4, -2, 0, 2, 4, 6, 8],
    ['menos oito', 'menos seis', 'menos quatro', 'menos dois', 'zero', 'dois', 'quatro', 'seis', 'oito'],
    rotation=46
)

plt.grid(True)
plt.show()

# %%
# personalizando as linhas
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, label='Linear', color='red')
plt.plot(x, x**2, label='Quadrática', color='blue')
plt.plot(x, x**3, label='Cúbica', color='green')

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
# personalizando as linhas
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, label='Linear', color='red', linewidth=4)
plt.plot(x, x**2, label='Quadrática', color='blue', linewidth=2)
plt.plot(x, x**3, label='Cúbica', color='green', linewidth=1)

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
# personalizando as linhas
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, label='Linear', color='red', linewidth=4, alpha=0.2)
plt.plot(x, x**2, label='Quadrática', color='blue', linewidth=2)
plt.plot(x, x**3, label='Cúbica', color='green', linewidth=1)

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
# personalizando as linhas
start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, 'r--', label='Linear', linewidth=2)
plt.plot(x, x**2, 'b-.', label='Quadrática', linewidth=2)
plt.plot(x, x**3, 'g:', label='Cúbica', linewidth=2)

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
# realizando marcação no gráfico
from matplotlib.patches import ArrowStyle

start = -2
end = 2

x = np.linspace(start, end, 100)

plt.plot(x, x, 'r--', label='Linear', linewidth=2)
plt.plot(x, x**2, 'b-.', label='Quadrática', linewidth=2)
plt.plot(x, x**3, 'g:', label='Cúbica', linewidth=2)

plt.title('Exemplo de Gráfico com Personalização', size=16)
plt.xlabel('Eixo X', size=14, style='italic')
plt.ylabel('Eixo Y', size=14, style='italic')
plt.legend()

#anotações
plt.annotate('Aqui', xy=(0.5, 4), color='red')

plt.annotate(
  'Acolá',
  xy=(0.0, 0.0),
  xytext=(1.0, 6.0),
  arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue') 
)

plt.xlim(start, end)

plt.grid(True)
plt.show()

# %%
x = np.linspace(0, 1.5, 100)

labels = [r'$x$', r'$x$', r'$x$', r'$x$']
plt.stackplot(x, x, x**2, x**3, x**4, labels=labels)
plt.legend(loc='upper left')
plt.show()

# %%
x = np.linspace(-2, 2, 100)

# %%
plt.plot(x, x)
